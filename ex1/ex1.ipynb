# %%
import numpy as np
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
columns = ['population','profit']
df_1 = pd.read_csv('./data/ex1data1.txt',names=columns)
#df_1['bias'] = 1
#df_1.head()
df_1.insert(1,'bias',1)
df_1.head()
# Out:
#    population  bias   profit
# 0      6.1101     1  17.5920
# 1      5.5277     1   9.1302
# 2      8.5186     1  13.6620
# 3      7.0032     1  11.8540
# 4      5.8598     1   6.8233

# %%
trace1 = go.Scatter(
    x = df_1['population'],
    y = df_1['profit'],
    mode = "markers",
    marker = dict(color='cray')
)

layout = go.Layout(
    xaxis = dict(title='population',
                ticklen = 5,
                gridwidth = 2 
                ),
    yaxis = dict(title = 'profit',
                ticklen = 5,
                gridwidth = 2)
)
data = [trace1]
fig = dict(data=data,layout=layout)
py.iplot(fig,filename='scatter_point')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-458bed9eb8ff> in <module>()
#      17 data = [trace1]
#      18 fig = dict(data=data,layout=layout)
# ---> 19 py.iplot(fig,filename='scatter_point')
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     129     if 'auto_open' not in plot_options:
#     130         plot_options['auto_open'] = False
# --> 131     url = plot(figure_or_data, **plot_options)
#     132
#     133     if isinstance(figure_or_data, dict):
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     222     data = fig.get('data', [])
#     223     plot_options['layout'] = fig.get('layout', {})
# --> 224     response = v1.clientresp(data, **plot_options)
#     225
#     226     # Check if the url needs a secret key
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      76     kwargs['verify'] = config.get_config()['plotly_ssl_verification']
#      77     try:
# ---> 78         response = requests.request(method, url, **kwargs)
#      79     except RequestException as e:
#      80         # The message can be an exception. E.g., MaxRetryError.
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     377         try:
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     253     def recv(self, *args, **kwargs):
#     254         try:
# --> 255             data = self.connection.recv(*args, **kwargs)
#     256         except OpenSSL.SSL.SysCallError as e:
#     257             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /home/wangyuren/.local/lib/python2.7/site-packages/OpenSSL/SSL.pyc in recv(self, bufsiz, flags)
#    1301             result = _lib.SSL_peek(self._ssl, buf, bufsiz)
#    1302         else:
# -> 1303             result = _lib.SSL_read(self._ssl, buf, bufsiz)
#    1304         self._raise_ssl_error(self._ssl, result)
#    1305         return _ffi.buffer(buf, result)[:]
#
# KeyboardInterrupt:

# %%
df_1[df_1['profit'] < 0].sum()

# %%
#m = df_1['population'].as_matrix().size
#X = df_1['population'].as_matrix()
#y = df_1['profit'].as_matrix()
#def cost(theta,X,y):
#    return ((1. /(2 * m)) * np.dot((y - np.dot(theta,X)).T, y - np.dot(theta,X)))

# %%
#cost(np.array([0] * m),X,y)

# %%
X = df_1[[0,1]]
#X.head()
print X.size
y = df_1[[2]]
print y.size
m = X.shape[0]
print m
print y.shape
#y.head()
# Out:
# 194
# 97
# 97
# (97, 1)

# %%
def cost(theta,X,y,size):
    #print np.dot(theta.T,X)
    #print np.dot(theta.T,X).transpose()
    #theta.shape = (2,1)
    #print X.shape
    #print (y - np.dot(theta,X)).T.shape
    #print np.array([[ 32.07273388]]).shape
    #print np.dot( y - np.dot(theta,X), (y - np.dot(theta,X)).T).shape
    #print np.dot(X,theta)
    #print y - np.dot(X,theta).reshape(m,
    return float((1.0 / (2 * m )) *  np.dot((y - np.dot(X,theta).reshape(size,1)).T, y - np.dot(X,theta).reshape(size,1)))

# %%
cost(np.array([0,0]).reshape(2,1),X,y,m)
# Out:
# 32.072733877455676

# %%
iterations = 15000
alpha = 0.01 #learning rate
def gradientdecent(X,y,size,inittheta=np.array([0,0]).reshape(2,1)):
    res = inittheta
    #print np.dot(X,res).shape
    #print y.shape
    #print np.dot(X,res) - y
    #print np.dot(X.T,(np.dot(X,res) - y))
    thetahist = []
    for _ in xrange(iterations):
        thetahist.append(res)
        res = res - (alpha * 1.0 / size) * np.dot(X.T,(np.dot(X,res) - y))
    print res
    return res,thetahist

# %%
t,thetahist = gradientdecent(X,y,m)
t.shape
# Out:
# [[ 1.19303364]
#  [-3.89578088]]
# (2, 1)

# %%
trace1 = go.Scatter(
    x = df_1['population'],
    y = df_1['profit'],
    mode = "markers",
    marker = dict(color='red')
)
trace2 = go.Scatter(
    x = df_1['population'],
    y = np.dot(df_1[[0,1]] ,t),
    mode = "lines",
    marker = dict(color='green')
)
data = [trace1,trace2]
py.iplot(data,name='reg.pdf')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c9b8d36d7aec> in <module>()
#      12 )
#      13 data = [trace1,trace2]
# ---> 14 py.iplot(data,name='reg.pdf')
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     129     if 'auto_open' not in plot_options:
#     130         plot_options['auto_open'] = False
# --> 131     url = plot(figure_or_data, **plot_options)
#     132
#     133     if isinstance(figure_or_data, dict):
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     222     data = fig.get('data', [])
#     223     plot_options['layout'] = fig.get('layout', {})
# --> 224     response = v1.clientresp(data, **plot_options)
#     225
#     226     # Check if the url needs a secret key
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /home/wangyuren/.local/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      76     kwargs['verify'] = config.get_config()['plotly_ssl_verification']
#      77     try:
# ---> 78         response = requests.request(method, url, **kwargs)
#      79     except RequestException as e:
#      80         # The message can be an exception. E.g., MaxRetryError.
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /home/wangyuren/.local/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# KeyboardInterrupt:

# %%
trace3 = go.Scatter(
    x = range(150),
    y = map(lambda x:cost(x,X,y,m),thetahist),
    mode = "lines+markers",
    line = dict(color="blue",shape="spline")
)

layout3 = go.Layout(
    xaxis = dict(title="iter times"),
    yaxis = dict(title="cost")
)
fig = go.Figure(data=[trace3],layout=layout3)
py.iplot(fig,name="cost.pdf")

# %% [markdown]
# multiple linear regression

# %%
column = ['square','bedroom','price']
df_2 = pd.read_csv('./data/ex1data2.txt',names=column)
df_2.head()
# Out:
#    square  bedroom   price
# 0    2104        3  399900
# 1    1600        3  329900
# 2    2400        3  369000
# 3    1416        2  232000
# 4    3000        4  539900

# %%
X_2 = df_2[[0,1]]
y_2 = df_2[[2]]
print X_2.shape
print y_2.shape
print X_2['square'].head()
m_2 = X_2.shape[0]
print m_2
# Out:
# (47, 2)
# (47, 1)
# 0    2104
# 1    1600
# 2    2400
# 3    1416
# 4    3000
# Name: square, dtype: int64
# 47

# %%
trace4 = go.Scatter3d(
    x = X_2['square'],
    y = X_2['bedroom'],
    z = y_2['price'],
    mode = "markers"
    
)
py.iplot([trace4],name='3d plot1.pdf')

# %%
#cost(np.array([0,0,0]).reshape(3,1),X_2,y_2,m_2)

# %%
#gradientdecent(X_2,y_2,m_2,np.array([0.,0.,0.]).reshape(3,1))
# normalize the data:
# when the data is too big ,it will cause nan and cannot work anymore
norm_X_2 = X_2.copy()
#norm_y_2 = y_2.copy()
#print norm_X_2.mean(axis=0)
#print norm_X_2.std(axis=0)
norm_X_2 = (norm_X_2 - norm_X_2.mean(axis=0)) / norm_X_2.std(axis=0)
#norm_y_2 = (norm_y_2 - norm_y_2.mean()) / norm_y_2.std()
norm_X_2.insert(2,"bias",1.)
print norm_X_2
# Out:
#       square   bedroom  bias
# 0   0.130010 -0.223675   1.0
# 1  -0.504190 -0.223675   1.0
# 2   0.502476 -0.223675   1.0
# 3  -0.735723 -1.537767   1.0
# 4   1.257476  1.090417   1.0
# 5  -0.019732  1.090417   1.0
# 6  -0.587240 -0.223675   1.0
# 7  -0.721881 -0.223675   1.0
# 8  -0.781023 -0.223675   1.0
# 9  -0.637573 -0.223675   1.0
# 10 -0.076357  1.090417   1.0
# 11 -0.000857 -0.223675   1.0
# 12 -0.139273 -0.223675   1.0
# 13  3.117292  2.404508   1.0
# 14 -0.921956 -0.223675   1.0
# 15  0.376643  1.090417   1.0
# 16 -0.856523 -1.537767   1.0
# 17 -0.962223 -0.223675   1.0
# 18  0.765468  1.090417   1.0
# 19  1.296484  1.090417   1.0
# 20 -0.294048 -0.223675   1.0
# 21 -0.141790 -1.537767   1.0
# 22 -0.499157 -0.223675   1.0
# 23 -0.048673  1.090417   1.0
# 24  2.377392 -0.223675   1.0
# 25 -1.133356 -0.223675   1.0
# 26 -0.682873 -0.223675   1.0
# 27  0.661026 -0.223675   1.0
# 28  0.250810 -0.223675   1.0
# 29  0.800701 -0.223675   1.0
# 30 -0.203448 -1.537767   1.0
# 31 -1.259189 -2.851859   1.0
# 32  0.049477  1.090417   1.0
# 33  1.429868 -0.223675   1.0
# 34 -0.238682  1.090417   1.0
# 35 -0.709298 -0.223675   1.0
# 36 -0.958448 -0.223675   1.0
# 37  0.165243  1.090417   1.0
# 38  2.786350  1.090417   1.0
# 39  0.202993  1.090417   1.0
# 40 -0.423657 -1.537767   1.0
# 41  0.298626 -0.223675   1.0
# 42  0.712618  1.090417   1.0
# 43 -1.007523 -0.223675   1.0
# 44 -1.445423 -1.537767   1.0
# 45 -0.187090  1.090417   1.0
# 46 -1.003748 -0.223675   1.0

# %%
print cost(np.array([0,0,0]).reshape(3,1),norm_X_2,y_2,m_2)
print m_2
print norm_X_2.as_matrix()
print y_2
print type(y_2)
# Out:
# 31781471762.9
# 47
# [[  1.30009869e-01  -2.23675187e-01   1.00000000e+00]
#  [ -5.04189838e-01  -2.23675187e-01   1.00000000e+00]
#  [  5.02476364e-01  -2.23675187e-01   1.00000000e+00]
#  [ -7.35723065e-01  -1.53776691e+00   1.00000000e+00]
#  [  1.25747602e+00   1.09041654e+00   1.00000000e+00]
#  [ -1.97317285e-02   1.09041654e+00   1.00000000e+00]
#  [ -5.87239800e-01  -2.23675187e-01   1.00000000e+00]
#  [ -7.21881404e-01  -2.23675187e-01   1.00000000e+00]
#  [ -7.81023044e-01  -2.23675187e-01   1.00000000e+00]
#  [ -6.37573110e-01  -2.23675187e-01   1.00000000e+00]
#  [ -7.63567023e-02   1.09041654e+00   1.00000000e+00]
#  [ -8.56737193e-04  -2.23675187e-01   1.00000000e+00]
#  [ -1.39273340e-01  -2.23675187e-01   1.00000000e+00]
#  [  3.11729182e+00   2.40450826e+00   1.00000000e+00]
#  [ -9.21956312e-01  -2.23675187e-01   1.00000000e+00]
#  [  3.76643089e-01   1.09041654e+00   1.00000000e+00]
#  [ -8.56523009e-01  -1.53776691e+00   1.00000000e+00]
#  [ -9.62222960e-01  -2.23675187e-01   1.00000000e+00]
#  [  7.65467909e-01   1.09041654e+00   1.00000000e+00]
#  [  1.29648433e+00   1.09041654e+00   1.00000000e+00]
#  [ -2.94048269e-01  -2.23675187e-01   1.00000000e+00]
#  [ -1.41790005e-01  -1.53776691e+00   1.00000000e+00]
#  [ -4.99156507e-01  -2.23675187e-01   1.00000000e+00]
#  [ -4.86733818e-02   1.09041654e+00   1.00000000e+00]
#  [  2.37739217e+00  -2.23675187e-01   1.00000000e+00]
#  [ -1.13335621e+00  -2.23675187e-01   1.00000000e+00]
#  [ -6.82873089e-01  -2.23675187e-01   1.00000000e+00]
#  [  6.61026291e-01  -2.23675187e-01   1.00000000e+00]
#  [  2.50809813e-01  -2.23675187e-01   1.00000000e+00]
#  [  8.00701226e-01  -2.23675187e-01   1.00000000e+00]
#  [ -2.03448310e-01  -1.53776691e+00   1.00000000e+00]
#  [ -1.25918949e+00  -2.85185864e+00   1.00000000e+00]
#  [  4.94765729e-02   1.09041654e+00   1.00000000e+00]
#  [  1.42986760e+00  -2.23675187e-01   1.00000000e+00]
#  [ -2.38681627e-01   1.09041654e+00   1.00000000e+00]
#  [ -7.09298077e-01  -2.23675187e-01   1.00000000e+00]
#  [ -9.58447962e-01  -2.23675187e-01   1.00000000e+00]
#  [  1.65243186e-01   1.09041654e+00   1.00000000e+00]
#  [  2.78635031e+00   1.09041654e+00   1.00000000e+00]
#  [  2.02993169e-01   1.09041654e+00   1.00000000e+00]
#  [ -4.23656542e-01  -1.53776691e+00   1.00000000e+00]
#  [  2.98626458e-01  -2.23675187e-01   1.00000000e+00]
#  [  7.12617934e-01   1.09041654e+00   1.00000000e+00]
#  [ -1.00752294e+00  -2.23675187e-01   1.00000000e+00]
#  [ -1.44542274e+00  -1.53776691e+00   1.00000000e+00]
#  [ -1.87089985e-01   1.09041654e+00   1.00000000e+00]
#  [ -1.00374794e+00  -2.23675187e-01   1.00000000e+00]]
#      price
# 0   399900
# 1   329900
# 2   369000
# 3   232000
# 4   539900
# 5   299900
# 6   314900
# 7   198999
# 8   212000
# 9   242500
# 10  239999
# 11  347000
# 12  329999
# 13  699900
# 14  259900
# 15  449900
# 16  299900
# 17  199900
# 18  499998
# 19  599000
# 20  252900
# 21  255000
# 22  242900
# 23  259900
# 24  573900
# 25  249900
# 26  464500
# 27  469000
# 28  475000
# 29  299900
# 30  349900
# 31  169900
# 32  314900
# 33  579900
# 34  285900
# 35  249900
# 36  229900
# 37  345000
# 38  549000
# 39  287000
# 40  368500
# 41  329900
# 42  314000
# 43  299000
# 44  179900
# 45  299900
# 46  239500
# <class 'pandas.core.frame.DataFrame'>

# %%
theta_2,theta_hist_2 = gradientdecent(norm_X_2.as_matrix(),y_2,m_2,inittheta=np.array([0.,0.,0.]).reshape(3,1))
# Out:
# [[ 110631.05027884]
#  [  -6649.47427082]
#  [ 340412.65957447]]

# %%
trace5 = go.Scatter(
    x = range(1500),
    y = map(lambda x:cost(x,norm_X_2,norm_y_2,m_2),theta_hist_2),
    mode = "lines+markers",
    line = dict(color="yellow",shape="spline")
)

layout5 = go.Layout(
    xaxis = dict(title="iter times"),
    yaxis = dict(title="cost")
)
fig = go.Figure(data=[trace5],layout=layout5)
py.iplot(fig,name="cost.pdf")

# %%
print "Check of result: What is price of house with 1650 square feet and 3 bedrooms?"
ytest = np.array([1650.,3.])
y_norm_test = (ytest - X_2.mean(axis=0)) / X_2.std(axis=0)
#print X_2.mean(axis=0).shape
#print X_2.std(axis=0).shape
np.insert(y_norm_test,2,1.)
#y_norm_test = np.insert(y_norm_test.as_matrix(),2,1.)
# Out:
# Check of result: What is price of house with 1650 square feet and 3 bedrooms?

# %%
print theta_2.shape
print np.dot(theta_2.T,y_norm_test)
# Out:
# (3, 1)
# [  1.82861697e+08]
